# %% [markdown]
# # Interactive Crop Yield and Food Security Analysis for Karamoja

# %% [markdown]
# First let me read in the datasets

# %%
# %pip  install geopandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Uganda subcounties

# %%
import geopandas as gdp
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\SHAPEFILES\Uganda_Subcounties.dbf"
df_1=gdp.read_file(file_path)
df_1.head()
# Out:
#    OBJECTID   SNAME2014                                           geometry
# 0      1001     KAKOOGE  POLYGON ((32.36852 1.28129, 32.36862 1.28116, ...
# 1      1002     KALUNGI  POLYGON ((32.6512 1.43626, 32.65483 1.43618, 3...
# 2      1003   LWABIYATA  POLYGON ((32.44624 1.46113, 32.44397 1.45635, ...
# 3      1004   LWAMPANGA  POLYGON ((32.51158 1.52129, 32.51195 1.52123, ...
# 4      1005  NABISWEERA  POLYGON ((32.30877 1.2589, 32.30877 1.2589, 32...

# %%
df_1.columns
# Out:
# Index(['OBJECTID', 'SNAME2014', 'geometry'], dtype='object')

# %% [markdown]
# Uganda District

# %%
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\SHAPEFILES\Uganda_Districts.shp"
df_2=gdp.read_file(file_path)
df_2.head()
# Out:
#    OBJECTID DNAME2014                                           geometry
# 0         1    MASAKA  POLYGON ((32.00051 -0.60761, 32.00053 -0.60993...
# 1         2  ALEBTONG  POLYGON ((33.41593 2.14287, 33.4152 2.14219, 3...
# 2         3   BUKEDEA  POLYGON ((34.20871 1.23683, 34.20847 1.23637, ...
# 3         4     BUSIA  POLYGON ((34.01262 0.2441, 34.01199 0.24363, 3...
# 4         5    MOROTO  POLYGON ((34.90168 2.5668, 34.90168 2.5668, 34...

# %%
df_2.columns
# Out:
# Index(['OBJECTID', 'DNAME2014', 'geometry'], dtype='object')

# %% [markdown]
# Sorghum field boundaries

# %%
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\SHAPEFILES\Crop_Type_Map_Sorghum.shp"
df_3=gdp.read_file(file_path)
df_3.head()
# Out:
#     DN                                           geometry
# 0  212  POLYGON ((609120 466020, 609180 466020, 609180...
# 1  212  POLYGON ((608820 462780, 608880 462780, 608880...
# 2  212  POLYGON ((607620 460020, 607680 460020, 607680...
# 3  212  POLYGON ((606360 458280, 606420 458280, 606420...
# 4  212  POLYGON ((601260 457560, 601320 457560, 601320...

# %%
df_3.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 36424 entries, 0 to 36423
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DN        36424 non-null  int32
#  1   geometry  36424 non-null  geometry
# dtypes: geometry(1), int32(1)
# memory usage: 427.0 KB

# %%
df_3.columns
# Out:
# Index(['DN', 'geometry'], dtype='object')

# %% [markdown]
# Maize field boundaries

# %%
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\SHAPEFILES\Crop_Type_Map_Maize.shx"
df_4=gdp.read_file(file_path)
df_4.head()
# Out:
#    DN                                           geometry
# 0   6  POLYGON ((609732.781 467760, 609720 467760, 60...
# 1   6  POLYGON ((609840 467661.872, 609840 467640, 60...
# 2   6  POLYGON ((606540 464340, 606600 464340, 606600...
# 3   6  POLYGON ((614040 461640, 614160 461640, 614160...
# 4   6  POLYGON ((613320 460680, 613380 460680, 613380...

# %%
df_4.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 28233 entries, 0 to 28232
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DN        28233 non-null  int32
#  1   geometry  28233 non-null  geometry
# dtypes: geometry(1), int32(1)
# memory usage: 331.0 KB

# %%
df_4.columns
# Out:
# Index(['DN', 'geometry'], dtype='object')

# %% [markdown]
# # Tabels

# %% [markdown]
# Yeild population per subcounty

# %%
import pandas as pd
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\TABLES\Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv"
df_5=pd.read_csv(file_path)
df_5.head()
# Out:
#    OBJECTID       SUBCOUNTY_NAME DISTRICT_NAME    POP        Area Karamoja  \
# 0       263              KACHERI        KOTIDO  17244  1067176155        Y
# 1       264               KOTIDO        KOTIDO  52771   597575188        Y
# 2       265  KOTIDO TOWN COUNCIL        KOTIDO  27389    23972401        Y
# 3       266         NAKAPERIMORU        KOTIDO  38775   419111591        Y
# 4       267           PANYANGARA        KOTIDO  65704   880955930        Y
#
#    S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha     S_Area_Ha   M_Area_Ha  \
# 0  354.207411  1137.467019   7023.533691   6434.342449  528.124229
# 1  367.890523  1162.996687  13587.990760  12455.592640  824.767081
# 2  369.314177  1167.005832   1656.531855   1520.322052    8.561644
# 3  283.324569   852.366578   7087.823334   6761.488901   45.721712
# 4  373.836926  1283.859882  10398.249390  10111.198130  172.611914
#
#      S_Prod_Tot     M_Prod_Tot
# 0  2.279092e+06  600723.892900
# 1  4.582294e+06  959201.382500
# ...

# %% [markdown]
# Yield population per district

# %%
file_path=r"C:\Users\Administrator\Desktop\projects\Foodinsecurity\DATA\TABLES\Uganda_Karamoja_District_Crop_Yield_Population.csv"
df_6=pd.read_csv(file_path)
df_6.head()
# Out:
#    OBJECTID     NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  \
# 0        92     ABIM   90385  2771977106         449        1040
# 1        96   AMUDAT  101790  1643582836         205        1297
# 2        20  KAABONG  627057  7373606003         279         945
# 3        85   KOTIDO  243157  3641539808         331        1148
# 4         5   MOROTO  127811  3570160948         128         355
#
#    Crop_Area_Ha     S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot
# 0   5470.068394   3277.295971  1848.621855     1471506     1922567
# 1   5765.443719   2973.423860  2733.661014      609552     3545558
# 2  28121.672530  20544.194960  7394.416334     5731830     6987723
# 3  53032.649450  50247.443900  1751.372284    16631904     2010575
# 4   5954.814048   4741.748776  1190.050606      606944      422468

# %% [markdown]
# I now want to merge shapefile with tabels

# %%
subcounty_df=df_1.merge(df_5,left_on='SNAME2014',right_on='SUBCOUNTY_NAME')
district_df=df_2.merge(df_6,left_on='DNAME2014',right_on='NAME')

# %%
subcounty_df=subcounty_df.drop(['SUBCOUNTY_NAME'],axis=1)

# %%
subcounty_df.head()
# Out:
#    OBJECTID_x    SNAME2014                                           geometry  \
# 0        1023       IRIIRI  POLYGON ((34.51034 2.31072, 34.52164 2.30961, ...
# 1        1024       LOPEEI  POLYGON ((34.28353 2.90633, 34.28374 2.90631, ...
# 2        1025  LORENGECORA  MULTIPOLYGON (((34.2226 2.1944, 34.2228 2.1943...
# 3        1026       LOTOME  POLYGON ((34.57186 2.44447, 34.57233 2.44293, ...
# 4        1027       MATANY  POLYGON ((34.42408 2.47867, 34.42444 2.4786, 3...
#
#    OBJECTID_y DISTRICT_NAME    POP        Area Karamoja  S_Yield_Ha  \
# 0        1023         NAPAK  46979  1030623258        Y  229.299157
# 1        1024         NAPAK  18815   790782350        Y  108.156411
# 2        1025         NAPAK   2503   118997955        Y  184.081197
# 3        1026         NAPAK  17834   125857565        Y  128.555598
# 4        1027         NAPAK  29495   338252511        Y  130.007687
#
#     M_Yield_Ha  Crop_Area_Ha    S_Area_Ha    M_Area_Ha   S_Prod_Tot  \
# ...

# %%
district_df.head()
# Out:
#    OBJECTID_x      DNAME2014  \
# 0           5         MOROTO
# 1          20        KAABONG
# 2          54  NAKAPIRIPIRIT
# 3          80          NAPAK
# 4          85         KOTIDO
#
#                                             geometry  OBJECTID_y  \
# 0  POLYGON ((34.90168 2.5668, 34.90168 2.5668, 34...           5
# 1  POLYGON ((34.39005 3.4876, 34.39005 3.4876, 34...          20
# 2  POLYGON ((34.79348 2.14646, 34.79348 2.14646, ...          54
# 3  POLYGON ((34.55002 2.30703, 34.55002 2.30703, ...          80
# 4  POLYGON ((33.8213 2.97086, 33.80438 2.98321, 3...          85
#
#             NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  Crop_Area_Ha  \
# 0         MOROTO  127811  3570160948         128         355   5954.814048
# 1        KAABONG  627057  7373606003         279         945  28121.672530
# 2  NAKAPIRIPIRIT  146780  4216323900         356        1264  26372.698490
# 3          NAPAK  167625  4508782023         137         854  22944.296020
# ...

# %% [markdown]
# then i will save this datasets to my pc

# %%
subcounty_df.to_file('Uganda subcounty food sec.geojson',driver='GeoJSON')

# %%
district_df.to_file('Uganda districts food sec.geojson',driver='GeoJSON')

# %% [markdown]
# I will form a new data set providing field areas in hactres per subcounties(Agregating field area per subcounty) .
# This is done by merging subcounty df_1 with soghurm and maize field   boundareis  df_3 and df_4(spertial field joinig)

# %%
subcounty = df_1.to_crs("EPSG:32636")   #
maize = df_4.to_crs(subcounty.crs)
sorghum = df_3.to_crs(subcounty.crs)

# %%
maize["Field_Area_Ha"] = maize.geometry.area / 10_000
sorghum["Field_Area_Ha"] = sorghum.geometry.area / 10_000

# %%
import geopandas as gpd

maize_joined = gpd.sjoin(maize, subcounty, how="inner", predicate="within")
sorghum_joined = gpd.sjoin(sorghum, subcounty, how="inner", predicate="within")

# %%
maize_summary = maize_joined.groupby("SNAME2014")["Field_Area_Ha"].sum().reset_index()
maize_summary.rename(columns={"Field_Area_Ha": "Maize_Field_Area_Ha"}, inplace=True)

sorghum_summary = sorghum_joined.groupby("SNAME2014")["Field_Area_Ha"].sum().reset_index()
sorghum_summary.rename(columns={"Field_Area_Ha": "Sorghum_Field_Area_Ha"}, inplace=True)

# %%
subcounty = subcounty.merge(maize_summary, on="SNAME2014", how="left")
subcounty = subcounty.merge(sorghum_summary, on="SNAME2014", how="left")

# %%
subcounty.head()
# Out:
#    OBJECTID   SNAME2014                                           geometry  \
# 0      1001     KAKOOGE  POLYGON ((429747.66 141629.744, 429758.903 141...
# 1      1002     KALUNGI  POLYGON ((461199.573 158753.636, 461603.412 15...
# 2      1003   LWABIYATA  POLYGON ((438399.132 161506.851, 438146.636 16...
# 3      1004   LWAMPANGA  POLYGON ((445669.847 168154.503, 445711.136 16...
# 4      1005  NABISWEERA  POLYGON ((423099.812 139156.729, 423099.82 139...
#
#    Maize_Field_Area_Ha  Sorghum_Field_Area_Ha
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN

# %%
subcounty[['Maize_Field_Area_Ha','Sorghum_Field_Area_Ha']].isnull().sum()
# Out:
# Maize_Field_Area_Ha      1321
# Sorghum_Field_Area_Ha    1324
# dtype: int64

# %% [markdown]
# # Data cleaning

# %%
subcounty_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID_x     59 non-null     int64
#  1   SNAME2014      59 non-null     object
#  2   geometry       59 non-null     geometry
#  3   OBJECTID_y     59 non-null     int64
#  4   DISTRICT_NAME  59 non-null     object
#  5   POP            59 non-null     int64
#  6   Area           59 non-null     int64
#  7   Karamoja       59 non-null     object
#  8   S_Yield_Ha     59 non-null     float64
#  9   M_Yield_Ha     59 non-null     float64
#  10  Crop_Area_Ha   59 non-null     float64
#  11  S_Area_Ha      59 non-null     float64
#  12  M_Area_Ha      59 non-null     float64
#  13  S_Prod_Tot     59 non-null     float64
#  14  M_Prod_Tot     59 non-null     float64
# dtypes: float64(7), geometry(1), int64(4), object(3)
# memory usage: 7.0+ KB

# %%
district_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID_x    7 non-null      int64
#  1   DNAME2014     7 non-null      object
#  2   geometry      7 non-null      geometry
#  3   OBJECTID_y    7 non-null      int64
#  4   NAME          7 non-null      object
#  5   POP           7 non-null      int64
#  6   Area          7 non-null      int64
#  7   S_Yield_Ha    7 non-null      int64
#  8   M_Yield_Ha    7 non-null      int64
#  9   Crop_Area_Ha  7 non-null      float64
#  10  S_Area_Ha     7 non-null      float64
#  11  M_Area_Ha     7 non-null      float64
#  12  S_Prod_Tot    7 non-null      int64
#  13  M_Prod_Tot    7 non-null      int64
# dtypes: float64(3), geometry(1), int64(8), object(2)
# memory usage: 916.0+ bytes

# %% [markdown]
# I see no missing values

# %%
district_df.describe()
# Out:
#        OBJECTID_x  OBJECTID_y            POP          Area  S_Yield_Ha  \
# count    7.000000    7.000000       7.000000  7.000000e+00    7.000000
# mean    61.714286   61.714286  214943.571429  3.960853e+09  269.285714
# std     36.481567   36.481567  188604.280916  1.781860e+09  119.243049
# min      5.000000    5.000000   90385.000000  1.643583e+09  128.000000
# 25%     37.000000   37.000000  114800.500000  3.171069e+09  171.000000
# 50%     80.000000   80.000000  146780.000000  3.641540e+09  279.000000
# 75%     88.500000   88.500000  205391.000000  4.362553e+09  343.500000
# max     96.000000   96.000000  627057.000000  7.373606e+09  449.000000
#
#         M_Yield_Ha  Crop_Area_Ha     S_Area_Ha    M_Area_Ha    S_Prod_Tot  \
# count     7.000000      7.000000      7.000000     7.000000  7.000000e+00
# mean    986.142857  21094.520379  16737.636651  3983.947082  4.873098e+06
# std     321.566700  17363.854165  16625.963460  2678.911441  5.743724e+06
# ...

# %% [markdown]
# We have 7 districts with aggregated data.
#
# At district scale, no zeros appear in production variables — meaning aggregation smooths out the sparsity seen at subcounty level.
#
# The ranges are  wide but more stable:
#
# Population ranges 90,385 → 627,057.
#
# Crop areas are consistently in the thousands of hectares.
#
# Production is consistently in the millions.
#
# This means the district dataset is more reliable for analysis, since fewer missing values and clearer signals exist.

# %%
subcounty_df.describe()
# Out:
#         OBJECTID_x   OBJECTID_y            POP          Area  S_Yield_Ha  \
# count    59.000000    59.000000      59.000000  5.900000e+01   59.000000
# mean    791.135593   804.542373   26153.627119  4.702248e+08  256.422010
# std     277.920198   266.626196   21016.738870  4.921699e+08  121.448919
# min     263.000000   263.000000    1418.000000  2.121209e+06  108.156411
# 25%     598.500000   599.500000   11630.500000  9.177676e+07  133.876013
# 50%     810.000000   925.000000   21999.000000  3.095774e+08  239.047878
# 75%     982.500000   980.500000   38233.000000  6.553768e+08  344.245856
# max    1320.000000  1320.000000  100919.000000  2.069555e+09  560.313070
#
#         M_Yield_Ha  Crop_Area_Ha     S_Area_Ha    M_Area_Ha    S_Prod_Tot  \
# count    59.000000     59.000000     59.000000    59.000000  5.900000e+01
# mean    845.078821   2502.770273   1985.838890   472.684662  5.779463e+05
# std     401.435681   3060.248057   2866.138229   701.150863  9.541010e+05
# ...

# %% [markdown]
# Many variables have zeros as minimum (e.g., M_Yield_Ha, M_Area_Ha, M_Prod_Tot). This confirms that some subcounties either lack maize production or have missing/unrecorded values.
#
# The ranges are very wide:
#
# Population varies from 1,418 → 100,919.
#
# Crop areas vary from fractions of a hectare → over 13,000 ha.
#
# Production varies from 0 → over 4.5 million units.
#
# This suggests high inequality across subcounties — only a few produce a lot, while many produce little or none.

# %%
subcounty.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               1382 non-null   int64
#  1   SNAME2014              1382 non-null   object
#  2   geometry               1382 non-null   geometry
#  3   Maize_Field_Area_Ha    61 non-null     float64
#  4   Sorghum_Field_Area_Ha  58 non-null     float64
# dtypes: float64(2), geometry(1), int64(1), object(1)
# memory usage: 54.1+ KB

# %% [markdown]
# this data has a lot of missing values and we are going to deal with it. I n this case we will just drop the raws with missing values  cos the data set sugest that those particular subcounties with missing values  had no maize fields or sorghum fields or may be our dataset never covered the fields in those areas

# %%
subcounty=subcounty.dropna(subset=['Maize_Field_Area_Ha','Sorghum_Field_Area_Ha'])

# %%
subcounty.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 53 entries, 22 to 1365
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               53 non-null     int64
#  1   SNAME2014              53 non-null     object
#  2   geometry               53 non-null     geometry
#  3   Maize_Field_Area_Ha    53 non-null     float64
#  4   Sorghum_Field_Area_Ha  53 non-null     float64
# dtypes: float64(2), geometry(1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
subcounty.describe()
# Out:
#           OBJECTID  Maize_Field_Area_Ha  Sorghum_Field_Area_Ha
# count    53.000000            53.000000              53.000000
# mean    751.509434           651.656034            1198.896458
# std     304.030592           846.271930            1172.375468
# min     149.000000             0.002122               0.009781
# 25%     595.000000           152.280000             327.960000
# 50%     768.000000           450.000000             820.080000
# 75%     982.000000           826.200000            1828.080000
# max    1320.000000          4285.440000            4777.200000

# %% [markdown]
# The whole of our three data set are now clean good to start EDA

# %%
subcounty.to_file('Areas in hactres cultivated with maize and sorgum.geojson',driver='GeoJSON')

# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Yeild distrbution at subcounty level

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))
sns.histplot(subcounty_df["M_Yield_Ha"], bins=15, kde=True, ax=axes[0], color="green")
axes[0].set_title("Maize Yield/Ha (Subcounty)")

sns.histplot(subcounty_df["S_Yield_Ha"], bins=15, kde=True, ax=axes[1], color="orange")
axes[1].set_title("Sorghum Yield/Ha (Subcounty)")
plt.show()

# %% [markdown]
# # Observation
# Mize yield has slightly negative distribution while sorghum yield has slightly positive distibution.
#
# For  maize yeild those farms with high areea for cultivation are likely to do well than those with low cultivated area. This is vise versa for soghum

# %% [markdown]
# District level

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="NAME", y="POP", data=district_df, color="orange")
plt.xticks(rotation=45)
plt.ylabel("Population")
plt.title("Population per District")
plt.show()

# %% [markdown]
# # Observation
#
# Kabong has the highest population and so it is an area worth focussing on

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))
sns.histplot(district_df["M_Yield_Ha"], bins=15, kde=True, ax=axes[0], color="green")
axes[0].set_title("Maize Yield/Ha (District)")

sns.histplot(district_df["S_Yield_Ha"], bins=15, kde=True, ax=axes[1], color="orange")
axes[1].set_title("Sorghum Yield/Ha (District)")
plt.show()

# %% [markdown]
# Yiel distribution at district level

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="NAME", y="M_Yield_Ha", data=district_df, color="green", label="Maize")
sns.barplot(x="NAME", y="S_Yield_Ha", data=district_df, color="orange", alpha=0.6, label="Sorghum")
plt.xticks(rotation=45)
plt.ylabel("Yield/Ha")
plt.title("Average Maize vs Sorghum Yield per District")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(district_df["NAME"], district_df["M_Prod_Tot"], label="Maize",  color="green")
plt.bar(district_df["NAME"], district_df["S_Prod_Tot"], bottom=district_df["M_Prod_Tot"], 
        label="Sorghum", alpha=0.6, color="orange")
plt.xticks(rotation=45)
plt.ylabel("Yield/Ha")
plt.title("Average Maize vs Sorghum Production in kg per District")
plt.legend()
plt.show()

# %% [markdown]
# # Observation
# In the first chart geenerally maize yield  per hactres across all distict is higher compared to sorghum and in district such us Moroto the maize and sorghum yield are both very low and the food in security in such areas are the ones that need to be adressed
#
# In the second chart it is checking on total production of maize and  sorgum in kg per district and we can conclude that even though maize has higher yield per hactres than sorghum its general productivity is still very low this may be due to the fact that fiels allocated for maize cultivation are few compared to fields allocated for sorghum .

# %% [markdown]
# Yield distrbution at subcounty level

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="SNAME2014", y="M_Yield_Ha", data=subcounty_df, color="green", label="Maize")
sns.barplot(x="SNAME2014", y="S_Yield_Ha", data=subcounty_df, color="orange", alpha=0.6, label="Sorghum")
plt.xticks(rotation=90)
plt.ylabel("Yield/Ha")
plt.title("Average Maize vs Sorghum Yield per subcounty")
plt.legend()
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
# Hear what i did is just narrowing down the conclusion made in crop yield in district level to crop yield at subcounty level
#
# And it is clear cos tou can see there are some subcounties zero maize yield while othes are even verry low

# %% [markdown]
# Identifying food insecure areas

# %%
subcounty_df["Maize_PerCap"] = subcounty_df["M_Prod_Tot"] / subcounty_df["POP"]
subcounty_df["Sorghum_PerCap"] = subcounty_df["S_Prod_Tot"] / subcounty_df["POP"]

print(subcounty_df.nsmallest(5, "Maize_PerCap")[["SNAME2014", "Maize_PerCap"]])
print(subcounty_df.nsmallest(5, "Sorghum_PerCap")[["SNAME2014", "Sorghum_PerCap"]])
# Out:
#             SNAME2014  Maize_PerCap
# 7   SOUTHERN DIVISION      0.000000
# 35  SOUTHERN DIVISION      0.000000
# 36  SOUTHERN DIVISION      0.000000
# 51  SOUTHERN DIVISION      0.000000
# 8   NORTHERN DIVISION      0.006455
#             SNAME2014  Sorghum_PerCap
# 8   NORTHERN DIVISION        0.002413
# 19  NORTHERN DIVISION        0.002413
# 34  NORTHERN DIVISION        0.002413
# 46  NORTHERN DIVISION        0.002413
# 50  NORTHERN DIVISION        0.002413

# %% [markdown]
# checking on correlation

# %%
plt.figure(figsize=(8,6))
sns.heatmap(subcounty_df[["M_Yield_Ha", "S_Yield_Ha", "M_Area_Ha", "S_Area_Ha", "POP"]].corr(), 
            annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap (Subcounty Level)")
plt.show()

# %% [markdown]
# # Observation
#
# Maize and Sorghum yields per hectare (M_Yield_Ha vs S_Yield_Ha) are positively correlated (0.69) → areas performing better in maize also tend to do better in sorghum.
#
# Population (POP) has weak correlations with yields but shows a moderate correlation with sorghum area (S_Area_Ha = 0.43). This means larger populations do not automatically translate into higher productivity.
#
# Cultivated area and yields are not strongly correlated, suggesting that expansion of land is not enough; productivity depends on other factors (drought, inputs, soil quality, pests).

# %% [markdown]
# Distribution of Crop Areas

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

sns.histplot(subcounty["Maize_Field_Area_Ha"], bins=15, kde=True, color="green", ax=axes[0])
axes[0].set_title("Distribution of Maize Field Area (Ha)")

sns.histplot(subcounty["Sorghum_Field_Area_Ha"], bins=15, kde=True, color="orange", ax=axes[1])
axes[1].set_title("Distribution of Sorghum Field Area (Ha)")

plt.show()

# %% [markdown]
# # Observation
# This graphs sugest that the land under cultivation with sorghum is higher compared  to maize this raisng alot of question cos from earlier graph we had learned that Maize yield in karamoja per hactres is higher compared to sorghum yield.
#
#
# ther migt be several resons for this

# %%
area_summary = subcounty.groupby("SNAME2014")[["Maize_Field_Area_Ha", "Sorghum_Field_Area_Ha"]].sum().reset_index()


area_summary.plot(x="SNAME2014", kind="bar", stacked=False, figsize=(14,6))
plt.xticks(rotation=90)
plt.ylabel("Area (Ha)")
plt.title("Maize vs Sorghum Field Area by Subcounty")
plt.show()

# %%
subcounty.plot(column="Maize_Field_Area_Ha", cmap="Greens", legend=True, figsize=(8,6))
plt.title("Spatial Distribution of Maize Field Area")
plt.show()

subcounty.plot(column="Sorghum_Field_Area_Ha", cmap="Oranges", legend=True, figsize=(8,6))
plt.title("Spatial Distribution of Sorghum Field Area")
plt.show()

# %% [markdown]
# # conclusion
# Karamoja is soghurm-dependent—if sorhgum fails due to drought, food security will be severely threatened.
#
# Sorghum, traditionally more drought-resistant, is underperforming → NGOs could investigate whether pest/disease outbreaks or poor seed varieties are driving the low yields eventhough generally it produces more in kg as compared to maize its yiel per hectres is waanting an issue that need to be looked into to avoid subjecting vast lands for soghum cultivation and nelecting maize
#
# District-level differences (e.g., Moroto and Abim underperforming) suggest targeted interventions are needed rather than uniform support across all districts.
#
# Low correlation between population and yield highlights the risk of hidden food insecurity hotspots—some densely populated subcounties(e.g subcountie in Kabong) may be at high risk even if yields look average.
